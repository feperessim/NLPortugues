# %% [markdown]
# <img src="https://github.com/alan-barzilay/NLPortugues/blob/master/imagens/logo_nlportugues.png?raw=true"  style="height:65%" align="right">
#
#
# # Lista 5 - Vanishing & Exploding Gradient
# **Nome: Felipe de Lima Peressim**
#
# **Numero Usp: 11823558**
#
#
#
#
#
#
#
#
#
# ______________

# %% [markdown]
# Nessa lista exploraremos alguns problemas que podemos encontrar ao treinarmos uma rede recorrente. Esses problemas não são únicos das redes recorrentes, qualquer rede profunda pode sofrer de vanishing e exploding gradient mas as redes recorrentes são especialmente instaveis devido a utilização da mesma matriz de pesos repetidas vezes.
#
# Começaremos explorando o exploding gradient e alguns de seus sintomas, em seguida utilizaremos gradient cliping para combate-lo.
# Por fim estudaremos uma rede que sofre de vanishing gradient e utilizaremos o [TensorBoard](??) para visualizar os gradientes e pesos da rede para entender melhor sua dinâmica. Exploraremos tambem algumas maneiras de combater o vanishing gradient e como elas alteram a dinâmica da rede através do TensorBoard.
#
#
#
# Para essa aula é necessario instalar o TensorBoard

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
# %load_ext tensorboard

from sklearn.datasets import make_circles
from numpy import where
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.initializers import RandomUniform





from utils import ExtendedTensorBoard

# %% [markdown]
# # Exploding
#
# Para essa parte da lista nós preparamos uma rede, note como a *loss* cresce exponencialmente até virar infinita e logo em seguida NaN. Esse é um sintoma classico de exploding gradient. O gradiente está tão elevado que a cada etapa de backpropagation o passo de atualização dos parametros leva a um aumento na *loss* e isso segue crescendo até que exploda.

# %%
def f1(x):
    return 5+ 10*x

xs = [x for x in range(100)]
ys = [f1(x) for x in range(100)]

# %%
opt = keras.optimizers.SGD()
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer=opt, loss="mean_squared_error")
model.fit(xs,ys,epochs=400)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 990us/step - loss: 971110157910016.0000
# Epoch 2/400
# 4/4 [==============================] - 0s 948us/step - loss: 565105687507918664298779377664.0000
# Epoch 3/400
# 4/4 [==============================] - 0s 2ms/step - loss: inf
# Epoch 4/400
# 4/4 [==============================] - 0s 2ms/step - loss: inf
# Epoch 5/400
# 4/4 [==============================] - 0s 2ms/step - loss: inf
# Epoch 6/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 7/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 8/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 9/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 10/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 11/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 12/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 13/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 14/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 15/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 16/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 17/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 18/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 19/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 20/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 21/400
# 4/4 [==============================] - 0s 5ms/step - loss: nan
# Epoch 22/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 23/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 24/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 25/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 26/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 27/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 28/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 29/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 30/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 31/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 32/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 33/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 34/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 35/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 36/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 37/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 38/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 39/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 40/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 41/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 42/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 43/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 44/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 45/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 46/400
# 4/4 [==============================] - 0s 5ms/step - loss: nan
# Epoch 47/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 48/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 49/400
# 4/4 [==============================] - 0s 5ms/step - loss: nan
# Epoch 50/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 51/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 52/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 53/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 54/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 55/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 56/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 57/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 58/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 59/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 60/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 61/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 62/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 63/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 64/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 65/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 66/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 67/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 68/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 69/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 70/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 71/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 72/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 73/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 74/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 75/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 76/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 77/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 78/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 79/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 80/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 81/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 82/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 83/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 84/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 85/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 86/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 87/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 88/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 89/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 90/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 91/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 92/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 93/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 94/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 95/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 96/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 97/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 98/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 99/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 100/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 101/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 102/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 103/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 104/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 105/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 106/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 107/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 108/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 109/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 110/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 111/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 112/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 113/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 114/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 115/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 116/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 117/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 118/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 119/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 120/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 121/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 122/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 123/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 124/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 125/400
# 4/4 [==============================] - 0s 949us/step - loss: nan
# Epoch 126/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 127/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 128/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 129/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 130/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 131/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 132/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 133/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 134/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 135/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 136/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 137/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 138/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 139/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 140/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 141/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 142/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 143/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 144/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 145/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 146/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 147/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 148/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 149/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 150/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 151/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 152/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 153/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 154/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 155/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 156/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 157/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 158/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 159/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 160/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 161/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 162/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 163/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 164/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 165/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 166/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 167/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 168/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 169/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 170/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 171/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 172/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 173/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 174/400
# 4/4 [==============================] - 0s 927us/step - loss: nan
# Epoch 175/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 176/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 177/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 178/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 179/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 180/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 181/400
# 4/4 [==============================] - 0s 908us/step - loss: nan
# Epoch 182/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 183/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 184/400
# 4/4 [==============================] - 0s 914us/step - loss: nan
# Epoch 185/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 186/400
# 4/4 [==============================] - 0s 924us/step - loss: nan
# Epoch 187/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 188/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 189/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 190/400
# 4/4 [==============================] - 0s 948us/step - loss: nan
# Epoch 191/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 192/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 193/400
# 4/4 [==============================] - 0s 970us/step - loss: nan
# Epoch 194/400
# 4/4 [==============================] - 0s 947us/step - loss: nan
# Epoch 195/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 196/400
# 4/4 [==============================] - 0s 912us/step - loss: nan
# Epoch 197/400
# 4/4 [==============================] - 0s 929us/step - loss: nan
# Epoch 198/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 199/400
# 4/4 [==============================] - 0s 897us/step - loss: nan
# Epoch 200/400
# 4/4 [==============================] - 0s 922us/step - loss: nan
# Epoch 201/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 202/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 203/400
# 4/4 [==============================] - 0s 960us/step - loss: nan
# Epoch 204/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 205/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 206/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 207/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 208/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 209/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 210/400
# 4/4 [==============================] - 0s 998us/step - loss: nan
# Epoch 211/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 212/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 213/400
# 4/4 [==============================] - 0s 983us/step - loss: nan
# Epoch 214/400
# 4/4 [==============================] - 0s 907us/step - loss: nan
# Epoch 215/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 216/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 217/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 218/400
# 4/4 [==============================] - 0s 870us/step - loss: nan
# Epoch 219/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 220/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 221/400
# 4/4 [==============================] - 0s 939us/step - loss: nan
# Epoch 222/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 223/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 224/400
# 4/4 [==============================] - 0s 933us/step - loss: nan
# Epoch 225/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 226/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 227/400
# 4/4 [==============================] - 0s 918us/step - loss: nan
# Epoch 228/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 229/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 230/400
# 4/4 [==============================] - 0s 904us/step - loss: nan
# Epoch 231/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 232/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 233/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 234/400
# 4/4 [==============================] - 0s 937us/step - loss: nan
# Epoch 235/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 236/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 237/400
# 4/4 [==============================] - 0s 825us/step - loss: nan
# Epoch 238/400
# 4/4 [==============================] - 0s 948us/step - loss: nan
# Epoch 239/400
# 4/4 [==============================] - 0s 902us/step - loss: nan
# Epoch 240/400
# 4/4 [==============================] - 0s 819us/step - loss: nan
# Epoch 241/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 242/400
# 4/4 [==============================] - 0s 801us/step - loss: nan
# Epoch 243/400
# 4/4 [==============================] - 0s 796us/step - loss: nan
# Epoch 244/400
# 4/4 [==============================] - 0s 892us/step - loss: nan
# Epoch 245/400
# 4/4 [==============================] - 0s 859us/step - loss: nan
# Epoch 246/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 247/400
# 4/4 [==============================] - 0s 927us/step - loss: nan
# Epoch 248/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 249/400
# 4/4 [==============================] - 0s 828us/step - loss: nan
# Epoch 250/400
# 4/4 [==============================] - 0s 717us/step - loss: nan
# Epoch 251/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 252/400
# 4/4 [==============================] - 0s 712us/step - loss: nan
# Epoch 253/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 254/400
# 4/4 [==============================] - 0s 948us/step - loss: nan
# Epoch 255/400
# 4/4 [==============================] - 0s 847us/step - loss: nan
# Epoch 256/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 257/400
# 4/4 [==============================] - 0s 878us/step - loss: nan
# Epoch 258/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 259/400
# 4/4 [==============================] - 0s 915us/step - loss: nan
# Epoch 260/400
# 4/4 [==============================] - 0s 858us/step - loss: nan
# Epoch 261/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 262/400
# 4/4 [==============================] - 0s 841us/step - loss: nan
# Epoch 263/400
# 4/4 [==============================] - 0s 832us/step - loss: nan
# Epoch 264/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 265/400
# 4/4 [==============================] - 0s 895us/step - loss: nan
# Epoch 266/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 267/400
# 4/4 [==============================] - 0s 859us/step - loss: nan
# Epoch 268/400
# 4/4 [==============================] - 0s 894us/step - loss: nan
# Epoch 269/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 270/400
# 4/4 [==============================] - 0s 876us/step - loss: nan
# Epoch 271/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 272/400
# 4/4 [==============================] - 0s 861us/step - loss: nan
# Epoch 273/400
# 4/4 [==============================] - 0s 834us/step - loss: nan
# Epoch 274/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 275/400
# 4/4 [==============================] - 0s 731us/step - loss: nan
# Epoch 276/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 277/400
# 4/4 [==============================] - 0s 764us/step - loss: nan
# Epoch 278/400
# 4/4 [==============================] - 0s 931us/step - loss: nan
# Epoch 279/400
# 4/4 [==============================] - 0s 947us/step - loss: nan
# Epoch 280/400
# 4/4 [==============================] - 0s 824us/step - loss: nan
# Epoch 281/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 282/400
# 4/4 [==============================] - 0s 869us/step - loss: nan
# Epoch 283/400
# 4/4 [==============================] - 0s 852us/step - loss: nan
# Epoch 284/400
# 4/4 [==============================] - 0s 804us/step - loss: nan
# Epoch 285/400
# 4/4 [==============================] - 0s 735us/step - loss: nan
# Epoch 286/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 287/400
# 4/4 [==============================] - 0s 863us/step - loss: nan
# Epoch 288/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 289/400
# 4/4 [==============================] - 0s 768us/step - loss: nan
# Epoch 290/400
# 4/4 [==============================] - 0s 783us/step - loss: nan
# Epoch 291/400
# 4/4 [==============================] - 0s 981us/step - loss: nan
# Epoch 292/400
# 4/4 [==============================] - 0s 744us/step - loss: nan
# Epoch 293/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 294/400
# 4/4 [==============================] - 0s 998us/step - loss: nan
# Epoch 295/400
# 4/4 [==============================] - 0s 832us/step - loss: nan
# Epoch 296/400
# 4/4 [==============================] - 0s 974us/step - loss: nan
# Epoch 297/400
# 4/4 [==============================] - 0s 747us/step - loss: nan
# Epoch 298/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 299/400
# 4/4 [==============================] - 0s 776us/step - loss: nan
# Epoch 300/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 301/400
# 4/4 [==============================] - 0s 762us/step - loss: nan
# Epoch 302/400
# 4/4 [==============================] - 0s 784us/step - loss: nan
# Epoch 303/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 304/400
# 4/4 [==============================] - 0s 736us/step - loss: nan
# Epoch 305/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 306/400
# 4/4 [==============================] - 0s 703us/step - loss: nan
# Epoch 307/400
# 4/4 [==============================] - 0s 971us/step - loss: nan
# Epoch 308/400
# 4/4 [==============================] - 0s 744us/step - loss: nan
# Epoch 309/400
# 4/4 [==============================] - 0s 762us/step - loss: nan
# Epoch 310/400
# 4/4 [==============================] - 0s 873us/step - loss: nan
# Epoch 311/400
# 4/4 [==============================] - 0s 725us/step - loss: nan
# Epoch 312/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 313/400
# 4/4 [==============================] - 0s 821us/step - loss: nan
# Epoch 314/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 315/400
# 4/4 [==============================] - 0s 851us/step - loss: nan
# Epoch 316/400
# 4/4 [==============================] - 0s 826us/step - loss: nan
# Epoch 317/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 318/400
# 4/4 [==============================] - 0s 976us/step - loss: nan
# Epoch 319/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 320/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 321/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 322/400
# 4/4 [==============================] - 0s 838us/step - loss: nan
# Epoch 323/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 324/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 325/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 326/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 327/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 328/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 329/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 330/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 331/400
# 4/4 [==============================] - 0s 953us/step - loss: nan
# Epoch 332/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 333/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 334/400
# 4/4 [==============================] - 0s 984us/step - loss: nan
# Epoch 335/400
# 4/4 [==============================] - 0s 851us/step - loss: nan
# Epoch 336/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 337/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 338/400
# 4/4 [==============================] - 0s 891us/step - loss: nan
# Epoch 339/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 340/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 341/400
# 4/4 [==============================] - 0s 888us/step - loss: nan
# Epoch 342/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 343/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 344/400
# 4/4 [==============================] - 0s 881us/step - loss: nan
# Epoch 345/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 346/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 347/400
# 4/4 [==============================] - 0s 925us/step - loss: nan
# Epoch 348/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 349/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 350/400
# 4/4 [==============================] - 0s 881us/step - loss: nan
# Epoch 351/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 352/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 353/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 354/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 355/400
# 4/4 [==============================] - 0s 884us/step - loss: nan
# Epoch 356/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 357/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 358/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 359/400
# 4/4 [==============================] - 0s 977us/step - loss: nan
# Epoch 360/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 361/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 362/400
# 4/4 [==============================] - 0s 989us/step - loss: nan
# Epoch 363/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 364/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 365/400
# 4/4 [==============================] - 0s 985us/step - loss: nan
# Epoch 366/400
# 4/4 [==============================] - 0s 806us/step - loss: nan
# Epoch 367/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 368/400
# 4/4 [==============================] - 0s 917us/step - loss: nan
# Epoch 369/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 370/400
# 4/4 [==============================] - 0s 896us/step - loss: nan
# Epoch 371/400
# 4/4 [==============================] - 0s 857us/step - loss: nan
# Epoch 372/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 373/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 374/400
# 4/4 [==============================] - 0s 890us/step - loss: nan
# Epoch 375/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 376/400
# 4/4 [==============================] - 0s 901us/step - loss: nan
# Epoch 377/400
# 4/4 [==============================] - 0s 890us/step - loss: nan
# Epoch 378/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 379/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 380/400
# 4/4 [==============================] - 0s 998us/step - loss: nan
# Epoch 381/400
# 4/4 [==============================] - 0s 930us/step - loss: nan
# Epoch 382/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 383/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 384/400
# 4/4 [==============================] - 0s 927us/step - loss: nan
# Epoch 385/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 386/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 387/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 388/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 389/400
# 4/4 [==============================] - 0s 980us/step - loss: nan
# Epoch 390/400
# 4/4 [==============================] - 0s 839us/step - loss: nan
# Epoch 391/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 392/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 393/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 394/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 395/400
# 4/4 [==============================] - 0s 976us/step - loss: nan
# Epoch 396/400
# 4/4 [==============================] - 0s 841us/step - loss: nan
# Epoch 397/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 398/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 399/400
# 4/4 [==============================] - 0s 831us/step - loss: nan
# Epoch 400/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan

# %% [markdown]
# ## Gradient Cliping
# ## <font color='blue'>Questão 1 </font>
#
#
# Utilizando a mesma arquitetura, realize gradient clipping no otimizador para contornar o problema de exploding gradient, compile e treine seu novo modelo.
# Você pode usar tanto o parametro `clipvalue` quanto `clipnorm` desde que sua rede consiga minimizar a loss.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

opt = keras.optimizers.SGD(lr=0.01, momentum=0.9, clipnorm=1)

model.compile(optimizer=opt, loss="mean_squared_error")

model.fit(xs,ys,epochs=400)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 846us/step - loss: 265586.6875
# Epoch 2/400
# 4/4 [==============================] - 0s 2ms/step - loss: 258574.5000
# Epoch 3/400
# 4/4 [==============================] - 0s 817us/step - loss: 245978.6875
# Epoch 4/400
# 4/4 [==============================] - 0s 2ms/step - loss: 230205.4062
# Epoch 5/400
# 4/4 [==============================] - 0s 2ms/step - loss: 212573.8750
# Epoch 6/400
# 4/4 [==============================] - 0s 2ms/step - loss: 194116.4219
# Epoch 7/400
# 4/4 [==============================] - 0s 2ms/step - loss: 174478.1875
# Epoch 8/400
# 4/4 [==============================] - 0s 2ms/step - loss: 157322.8750
# Epoch 9/400
# 4/4 [==============================] - 0s 1ms/step - loss: 140318.0781
# Epoch 10/400
# 4/4 [==============================] - 0s 2ms/step - loss: 124087.7891
# Epoch 11/400
# 4/4 [==============================] - 0s 2ms/step - loss: 108077.3672
# Epoch 12/400
# 4/4 [==============================] - 0s 2ms/step - loss: 93599.1875
# Epoch 13/400
# 4/4 [==============================] - 0s 2ms/step - loss: 79878.6406
# Epoch 14/400
# 4/4 [==============================] - 0s 2ms/step - loss: 67443.0625
# Epoch 15/400
# 4/4 [==============================] - 0s 2ms/step - loss: 56089.6562
# Epoch 16/400
# 4/4 [==============================] - 0s 1ms/step - loss: 45819.9141
# Epoch 17/400
# 4/4 [==============================] - 0s 2ms/step - loss: 36382.9492
# Epoch 18/400
# 4/4 [==============================] - 0s 2ms/step - loss: 27705.6016
# Epoch 19/400
# 4/4 [==============================] - 0s 2ms/step - loss: 20787.6660
# Epoch 20/400
# 4/4 [==============================] - 0s 2ms/step - loss: 14350.9814
# Epoch 21/400
# 4/4 [==============================] - 0s 2ms/step - loss: 9409.2666
# Epoch 22/400
# 4/4 [==============================] - 0s 3ms/step - loss: 5456.9868
# Epoch 23/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2689.8096
# Epoch 24/400
# 4/4 [==============================] - 0s 1ms/step - loss: 767.9712
# Epoch 25/400
# 4/4 [==============================] - 0s 2ms/step - loss: 40.5744
# Epoch 26/400
# 4/4 [==============================] - 0s 1ms/step - loss: 157.7653
# Epoch 27/400
# 4/4 [==============================] - 0s 2ms/step - loss: 231.2805
# Epoch 28/400
# 4/4 [==============================] - 0s 2ms/step - loss: 84.0042
# Epoch 29/400
# 4/4 [==============================] - 0s 2ms/step - loss: 17.7440
# Epoch 30/400
# 4/4 [==============================] - 0s 2ms/step - loss: 63.9216
# Epoch 31/400
# 4/4 [==============================] - 0s 2ms/step - loss: 18.8113
# Epoch 32/400
# 4/4 [==============================] - 0s 2ms/step - loss: 18.5615
# Epoch 33/400
# 4/4 [==============================] - 0s 2ms/step - loss: 7.8409
# Epoch 34/400
# 4/4 [==============================] - 0s 2ms/step - loss: 20.8800
# Epoch 35/400
# 4/4 [==============================] - 0s 2ms/step - loss: 6.6009
# Epoch 36/400
# 4/4 [==============================] - 0s 2ms/step - loss: 7.5047
# Epoch 37/400
# 4/4 [==============================] - 0s 2ms/step - loss: 7.4616
# Epoch 38/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.6571
# Epoch 39/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.7392
# Epoch 40/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.6321
# Epoch 41/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.8800
# Epoch 42/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.0327
# Epoch 43/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.5602
# Epoch 44/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2566
# Epoch 45/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3238
# Epoch 46/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7092
# Epoch 47/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1889
# Epoch 48/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1.4158
# Epoch 49/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9293
# Epoch 50/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7589
# Epoch 51/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5902
# Epoch 52/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4470
# Epoch 53/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3246
# Epoch 54/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3375
# Epoch 55/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2806
# Epoch 56/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1379
# Epoch 57/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1220
# Epoch 58/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1730
# Epoch 59/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1500
# Epoch 60/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0800
# Epoch 61/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0783
# Epoch 62/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1621
# Epoch 63/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1859
# Epoch 64/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2101
# Epoch 65/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2249
# Epoch 66/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1531
# Epoch 67/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2030
# Epoch 68/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1753
# Epoch 69/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1918
# Epoch 70/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2078
# Epoch 71/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1858
# Epoch 72/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1793
# Epoch 73/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1711
# Epoch 74/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2249
# Epoch 75/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2258
# Epoch 76/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2005
# Epoch 77/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2148
# Epoch 78/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2174
# Epoch 79/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1839
# Epoch 80/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1861
# Epoch 81/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2094
# Epoch 82/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2065
# Epoch 83/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1918
# Epoch 84/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1969
# Epoch 85/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2003
# Epoch 86/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2312
# Epoch 87/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2041
# Epoch 88/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2240
# Epoch 89/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2134
# Epoch 90/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2001
# Epoch 91/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2056
# Epoch 92/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2137
# Epoch 93/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1841
# Epoch 94/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2009
# Epoch 95/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1809
# Epoch 96/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1932
# Epoch 97/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2076
# Epoch 98/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2236
# Epoch 99/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1775
# Epoch 100/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2035
# Epoch 101/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1782
# Epoch 102/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1861
# Epoch 103/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2006
# Epoch 104/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2275
# Epoch 105/400
# 4/4 [==============================] - ETA: 0s - loss: 0.297 - 0s 858us/step - loss: 0.2254
# Epoch 106/400
# 4/4 [==============================] - 0s 799us/step - loss: 0.1888
# Epoch 107/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1936
# Epoch 108/400
# 4/4 [==============================] - 0s 813us/step - loss: 0.1910
# Epoch 109/400
# 4/4 [==============================] - 0s 849us/step - loss: 0.2160
# Epoch 110/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1898
# Epoch 111/400
# 4/4 [==============================] - 0s 787us/step - loss: 0.1948
# Epoch 112/400
# 4/4 [==============================] - 0s 815us/step - loss: 0.1804
# Epoch 113/400
# 4/4 [==============================] - 0s 957us/step - loss: 0.2131
# Epoch 114/400
# 4/4 [==============================] - 0s 831us/step - loss: 0.2139
# Epoch 115/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1741
# Epoch 116/400
# 4/4 [==============================] - 0s 818us/step - loss: 0.2070
# Epoch 117/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2033
# Epoch 118/400
# 4/4 [==============================] - 0s 854us/step - loss: 0.2056
# Epoch 119/400
# 4/4 [==============================] - 0s 816us/step - loss: 0.2278
# Epoch 120/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1999
# Epoch 121/400
# 4/4 [==============================] - 0s 920us/step - loss: 0.1963
# Epoch 122/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2107
# Epoch 123/400
# 4/4 [==============================] - 0s 872us/step - loss: 0.1992
# Epoch 124/400
# 4/4 [==============================] - 0s 851us/step - loss: 0.2120
# Epoch 125/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2040
# Epoch 126/400
# 4/4 [==============================] - 0s 873us/step - loss: 0.2044
# Epoch 127/400
# 4/4 [==============================] - 0s 911us/step - loss: 0.1641
# Epoch 128/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1970
# Epoch 129/400
# 4/4 [==============================] - 0s 844us/step - loss: 0.1919
# Epoch 130/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2125
# Epoch 131/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2103
# Epoch 132/400
# 4/4 [==============================] - 0s 912us/step - loss: 0.1969
# Epoch 133/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1864
# Epoch 134/400
# 4/4 [==============================] - 0s 853us/step - loss: 0.2288
# Epoch 135/400
# 4/4 [==============================] - 0s 978us/step - loss: 0.1787
# Epoch 136/400
# 4/4 [==============================] - 0s 930us/step - loss: 0.1979
# Epoch 137/400
# 4/4 [==============================] - 0s 822us/step - loss: 0.1923
# Epoch 138/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2316
# Epoch 139/400
# 4/4 [==============================] - 0s 835us/step - loss: 0.1976
# Epoch 140/400
# 4/4 [==============================] - 0s 955us/step - loss: 0.2177
# Epoch 141/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1982
# Epoch 142/400
# 4/4 [==============================] - 0s 741us/step - loss: 0.1924
# Epoch 143/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2047
# Epoch 144/400
# 4/4 [==============================] - 0s 852us/step - loss: 0.2079
# Epoch 145/400
# 4/4 [==============================] - 0s 841us/step - loss: 0.2142
# Epoch 146/400
# 4/4 [==============================] - 0s 921us/step - loss: 0.2188
# Epoch 147/400
# 4/4 [==============================] - 0s 731us/step - loss: 0.1949
# Epoch 148/400
# 4/4 [==============================] - 0s 1000us/step - loss: 0.1982
# Epoch 149/400
# 4/4 [==============================] - 0s 720us/step - loss: 0.2237
# Epoch 150/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1946
# Epoch 151/400
# 4/4 [==============================] - 0s 885us/step - loss: 0.2041
# Epoch 152/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2050
# Epoch 153/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1877
# Epoch 154/400
# 4/4 [==============================] - 0s 769us/step - loss: 0.2045
# Epoch 155/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2091
# Epoch 156/400
# 4/4 [==============================] - 0s 875us/step - loss: 0.1920
# Epoch 157/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1962
# Epoch 158/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1933
# Epoch 159/400
# 4/4 [==============================] - 0s 859us/step - loss: 0.1740
# Epoch 160/400
# 4/4 [==============================] - 0s 910us/step - loss: 0.2172
# Epoch 161/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2161
# Epoch 162/400
# 4/4 [==============================] - 0s 959us/step - loss: 0.2048
# Epoch 163/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2133
# Epoch 164/400
# 4/4 [==============================] - 0s 851us/step - loss: 0.2094
# Epoch 165/400
# 4/4 [==============================] - 0s 757us/step - loss: 0.1907
# Epoch 166/400
# 4/4 [==============================] - 0s 944us/step - loss: 0.1801
# Epoch 167/400
# 4/4 [==============================] - 0s 850us/step - loss: 0.2041
# Epoch 168/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1725
# Epoch 169/400
# 4/4 [==============================] - 0s 840us/step - loss: 0.1909
# Epoch 170/400
# 4/4 [==============================] - 0s 820us/step - loss: 0.1958
# Epoch 171/400
# 4/4 [==============================] - 0s 737us/step - loss: 0.1960
# Epoch 172/400
# 4/4 [==============================] - 0s 794us/step - loss: 0.2168
# Epoch 173/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2317
# Epoch 174/400
# 4/4 [==============================] - 0s 750us/step - loss: 0.1814
# Epoch 175/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1931
# Epoch 176/400
# 4/4 [==============================] - 0s 760us/step - loss: 0.2014
# Epoch 177/400
# 4/4 [==============================] - 0s 838us/step - loss: 0.1876
# Epoch 178/400
# 4/4 [==============================] - 0s 784us/step - loss: 0.1861
# Epoch 179/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1947
# Epoch 180/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1934
# Epoch 181/400
# 4/4 [==============================] - 0s 811us/step - loss: 0.1805
# Epoch 182/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1879
# Epoch 183/400
# 4/4 [==============================] - 0s 729us/step - loss: 0.1863
# Epoch 184/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2109
# Epoch 185/400
# 4/4 [==============================] - 0s 947us/step - loss: 0.1905
# Epoch 186/400
# 4/4 [==============================] - 0s 736us/step - loss: 0.2035
# Epoch 187/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2277
# Epoch 188/400
# 4/4 [==============================] - 0s 784us/step - loss: 0.1891
# Epoch 189/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1755
# Epoch 190/400
# 4/4 [==============================] - 0s 815us/step - loss: 0.1705
# Epoch 191/400
# 4/4 [==============================] - 0s 730us/step - loss: 0.2151
# Epoch 192/400
# 4/4 [==============================] - 0s 892us/step - loss: 0.2002
# Epoch 193/400
# 4/4 [==============================] - 0s 736us/step - loss: 0.2150
# Epoch 194/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2135
# Epoch 195/400
# 4/4 [==============================] - 0s 915us/step - loss: 0.2219
# Epoch 196/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2007
# Epoch 197/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2019
# Epoch 198/400
# 4/4 [==============================] - 0s 817us/step - loss: 0.2173
# Epoch 199/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1789
# Epoch 200/400
# 4/4 [==============================] - 0s 916us/step - loss: 0.1895
# Epoch 201/400
# 4/4 [==============================] - 0s 839us/step - loss: 0.1893
# Epoch 202/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1855
# Epoch 203/400
# 4/4 [==============================] - 0s 837us/step - loss: 0.1949
# Epoch 204/400
# 4/4 [==============================] - 0s 853us/step - loss: 0.1667
# Epoch 205/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1942
# Epoch 206/400
# 4/4 [==============================] - 0s 858us/step - loss: 0.1640
# Epoch 207/400
# 4/4 [==============================] - 0s 885us/step - loss: 0.1757
# Epoch 208/400
# 4/4 [==============================] - 0s 852us/step - loss: 0.2040
# Epoch 209/400
# 4/4 [==============================] - 0s 800us/step - loss: 0.2111
# Epoch 210/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1573
# Epoch 211/400
# 4/4 [==============================] - 0s 734us/step - loss: 0.1995
# Epoch 212/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1884
# Epoch 213/400
# 4/4 [==============================] - 0s 989us/step - loss: 0.2032
# Epoch 214/400
# 4/4 [==============================] - 0s 723us/step - loss: 0.1797
# Epoch 215/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1924
# Epoch 216/400
# 4/4 [==============================] - 0s 696us/step - loss: 0.2260
# Epoch 217/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1930
# Epoch 218/400
# 4/4 [==============================] - 0s 751us/step - loss: 0.2045
# Epoch 219/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2206
# Epoch 220/400
# 4/4 [==============================] - 0s 902us/step - loss: 0.2098
# Epoch 221/400
# 4/4 [==============================] - 0s 767us/step - loss: 0.1864
# Epoch 222/400
# 4/4 [==============================] - 0s 927us/step - loss: 0.2095
# Epoch 223/400
# 4/4 [==============================] - 0s 776us/step - loss: 0.1911
# Epoch 224/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2210
# Epoch 225/400
# 4/4 [==============================] - 0s 786us/step - loss: 0.2123
# Epoch 226/400
# 4/4 [==============================] - 0s 946us/step - loss: 0.2113
# Epoch 227/400
# 4/4 [==============================] - 0s 837us/step - loss: 0.2238
# Epoch 228/400
# 4/4 [==============================] - 0s 726us/step - loss: 0.1948
# Epoch 229/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2086
# Epoch 230/400
# 4/4 [==============================] - 0s 832us/step - loss: 0.2067
# Epoch 231/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2081
# Epoch 232/400
# 4/4 [==============================] - 0s 717us/step - loss: 0.2020
# Epoch 233/400
# 4/4 [==============================] - 0s 768us/step - loss: 0.2298
# Epoch 234/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1788
# Epoch 235/400
# 4/4 [==============================] - 0s 967us/step - loss: 0.2088
# Epoch 236/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1917
# Epoch 237/400
# 4/4 [==============================] - 0s 802us/step - loss: 0.1944
# Epoch 238/400
# 4/4 [==============================] - 0s 863us/step - loss: 0.2141
# Epoch 239/400
# 4/4 [==============================] - 0s 915us/step - loss: 0.2211
# Epoch 240/400
# 4/4 [==============================] - 0s 814us/step - loss: 0.1952
# Epoch 241/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1886
# Epoch 242/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1889
# Epoch 243/400
# 4/4 [==============================] - 0s 899us/step - loss: 0.2131
# Epoch 244/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1952
# Epoch 245/400
# 4/4 [==============================] - 0s 934us/step - loss: 0.1909
# Epoch 246/400
# 4/4 [==============================] - 0s 832us/step - loss: 0.2208
# Epoch 247/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2006
# Epoch 248/400
# 4/4 [==============================] - 0s 864us/step - loss: 0.1846
# Epoch 249/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2332
# Epoch 250/400
# 4/4 [==============================] - 0s 972us/step - loss: 0.2089
# Epoch 251/400
# 4/4 [==============================] - 0s 865us/step - loss: 0.1779
# Epoch 252/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2106
# Epoch 253/400
# 4/4 [==============================] - 0s 859us/step - loss: 0.2110
# Epoch 254/400
# 4/4 [==============================] - 0s 891us/step - loss: 0.2043
# Epoch 255/400
# 4/4 [==============================] - 0s 762us/step - loss: 0.2051
# Epoch 256/400
# 4/4 [==============================] - 0s 798us/step - loss: 0.1908
# Epoch 257/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2146
# Epoch 258/400
# 4/4 [==============================] - 0s 806us/step - loss: 0.1916
# Epoch 259/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1789
# Epoch 260/400
# 4/4 [==============================] - 0s 942us/step - loss: 0.1962
# Epoch 261/400
# 4/4 [==============================] - 0s 743us/step - loss: 0.2087
# Epoch 262/400
# 4/4 [==============================] - 0s 990us/step - loss: 0.2170
# Epoch 263/400
# 4/4 [==============================] - 0s 775us/step - loss: 0.1786
# Epoch 264/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2439
# Epoch 265/400
# 4/4 [==============================] - 0s 848us/step - loss: 0.1889
# Epoch 266/400
# 4/4 [==============================] - 0s 777us/step - loss: 0.1967
# Epoch 267/400
# 4/4 [==============================] - 0s 892us/step - loss: 0.2025
# Epoch 268/400
# 4/4 [==============================] - 0s 784us/step - loss: 0.2202
# Epoch 269/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2092
# Epoch 270/400
# 4/4 [==============================] - 0s 760us/step - loss: 0.1772
# Epoch 271/400
# 4/4 [==============================] - 0s 885us/step - loss: 0.1987
# Epoch 272/400
# 4/4 [==============================] - 0s 775us/step - loss: 0.1860
# Epoch 273/400
# 4/4 [==============================] - 0s 895us/step - loss: 0.1857
# Epoch 274/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1940
# Epoch 275/400
# 4/4 [==============================] - 0s 790us/step - loss: 0.1861
# Epoch 276/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2131
# Epoch 277/400
# 4/4 [==============================] - 0s 849us/step - loss: 0.1861
# Epoch 278/400
# 4/4 [==============================] - 0s 896us/step - loss: 0.2148
# Epoch 279/400
# 4/4 [==============================] - 0s 956us/step - loss: 0.1732
# Epoch 280/400
# 4/4 [==============================] - 0s 789us/step - loss: 0.1860
# Epoch 281/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1816
# Epoch 282/400
# 4/4 [==============================] - 0s 811us/step - loss: 0.2121
# Epoch 283/400
# 4/4 [==============================] - 0s 852us/step - loss: 0.2197
# Epoch 284/400
# 4/4 [==============================] - 0s 825us/step - loss: 0.2151
# Epoch 285/400
# 4/4 [==============================] - 0s 897us/step - loss: 0.2049
# Epoch 286/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2076
# Epoch 287/400
# 4/4 [==============================] - 0s 848us/step - loss: 0.2041
# Epoch 288/400
# 4/4 [==============================] - 0s 897us/step - loss: 0.2087
# Epoch 289/400
# 4/4 [==============================] - 0s 933us/step - loss: 0.2161
# Epoch 290/400
# 4/4 [==============================] - 0s 965us/step - loss: 0.1854
# Epoch 291/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2009
# Epoch 292/400
# 4/4 [==============================] - 0s 735us/step - loss: 0.2019
# Epoch 293/400
# 4/4 [==============================] - 0s 780us/step - loss: 0.1944
# Epoch 294/400
# 4/4 [==============================] - 0s 788us/step - loss: 0.2255
# Epoch 295/400
# 4/4 [==============================] - 0s 833us/step - loss: 0.2222
# Epoch 296/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1950
# Epoch 297/400
# 4/4 [==============================] - 0s 742us/step - loss: 0.2125
# Epoch 298/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2228
# Epoch 299/400
# 4/4 [==============================] - 0s 805us/step - loss: 0.2121
# Epoch 300/400
# 4/4 [==============================] - 0s 845us/step - loss: 0.2042
# Epoch 301/400
# 4/4 [==============================] - 0s 960us/step - loss: 0.1969
# Epoch 302/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1855
# Epoch 303/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2053
# Epoch 304/400
# 4/4 [==============================] - 0s 820us/step - loss: 0.1899
# Epoch 305/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2017
# Epoch 306/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2148
# Epoch 307/400
# 4/4 [==============================] - 0s 841us/step - loss: 0.1716
# Epoch 308/400
# 4/4 [==============================] - 0s 892us/step - loss: 0.1856
# Epoch 309/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2008
# Epoch 310/400
# 4/4 [==============================] - 0s 802us/step - loss: 0.2139
# Epoch 311/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2013
# Epoch 312/400
# 4/4 [==============================] - 0s 931us/step - loss: 0.2077
# Epoch 313/400
# 4/4 [==============================] - 0s 874us/step - loss: 0.2296
# Epoch 314/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2153
# Epoch 315/400
# 4/4 [==============================] - 0s 800us/step - loss: 0.1886
# Epoch 316/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1898
# Epoch 317/400
# 4/4 [==============================] - 0s 965us/step - loss: 0.2130
# Epoch 318/400
# 4/4 [==============================] - 0s 769us/step - loss: 0.1870
# Epoch 319/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1930
# Epoch 320/400
# 4/4 [==============================] - 0s 818us/step - loss: 0.1602
# Epoch 321/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1744
# Epoch 322/400
# 4/4 [==============================] - 0s 917us/step - loss: 0.1816
# Epoch 323/400
# 4/4 [==============================] - 0s 823us/step - loss: 0.1925
# Epoch 324/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1959
# Epoch 325/400
# 4/4 [==============================] - 0s 878us/step - loss: 0.1788
# Epoch 326/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1997
# Epoch 327/400
# 4/4 [==============================] - 0s 916us/step - loss: 0.1967
# Epoch 328/400
# 4/4 [==============================] - 0s 873us/step - loss: 0.2182
# Epoch 329/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2025
# Epoch 330/400
# 4/4 [==============================] - 0s 895us/step - loss: 0.1936
# Epoch 331/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2024
# Epoch 332/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1966
# Epoch 333/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2154
# Epoch 334/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2239
# Epoch 335/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2288
# Epoch 336/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2077
# Epoch 337/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2001
# Epoch 338/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2138
# Epoch 339/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1750
# Epoch 340/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1981
# Epoch 341/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1711
# Epoch 342/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2022
# Epoch 343/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1689
# Epoch 344/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1928
# Epoch 345/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2183
# Epoch 346/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2078
# Epoch 347/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1844
# Epoch 348/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2005
# Epoch 349/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1985
# Epoch 350/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1972
# Epoch 351/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1906
# Epoch 352/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2367
# Epoch 353/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1970
# Epoch 354/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1896
# Epoch 355/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1796
# Epoch 356/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1743
# Epoch 357/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1882
# Epoch 358/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2145
# Epoch 359/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1993
# Epoch 360/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1883
# Epoch 361/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2236
# Epoch 362/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1918
# Epoch 363/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2223
# Epoch 364/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2314
# Epoch 365/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2021
# Epoch 366/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2110
# Epoch 367/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2179
# Epoch 368/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2317
# Epoch 369/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1926
# Epoch 370/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2139
# Epoch 371/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1954
# Epoch 372/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1804
# Epoch 373/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2194
# Epoch 374/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1893
# Epoch 375/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1930
# Epoch 376/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2358
# Epoch 377/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1942
# Epoch 378/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2029
# Epoch 379/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2051
# Epoch 380/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2047
# Epoch 381/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1937
# Epoch 382/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1774
# Epoch 383/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2117
# Epoch 384/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1977
# Epoch 385/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1856
# Epoch 386/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2187
# Epoch 387/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1997
# Epoch 388/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1827
# Epoch 389/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1767
# Epoch 390/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2135
# Epoch 391/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1929
# Epoch 392/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2074
# Epoch 393/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1795
# Epoch 394/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2093
# Epoch 395/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1876
# Epoch 396/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1968
# Epoch 397/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1836
# Epoch 398/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2160
# Epoch 399/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2098
# Epoch 400/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1949

# %% [markdown]
# ________________________
#
#
#
# # Vanishing
#
# Lidar com Vanishing Gradient é muito mais desafiador do que com exploding gradient. Não é trivial determinar se o baixo desempenho de sua rede é causado por vanishing gradient uma vez que seus sintomas são relativamente genericos e ele pode ser apenas mais um dos fatores que prejudicam seu desempenho. Além disso não existe uma solução geral e definitiva como o gradient cliping em casos de explosão do gradiente.
#
# Preparamos algumas redes para poder explorar um caso mais simples de vanishing gradient e também uma possivel solução. Começamos gerando um dataset simples de classificação e treinamos uma rede rasa que obtem uma boa performance.
# Ao aprofundarmos essa rede podemos notar que sua performance cai drasticamente se tornando quase tão eficiente quanto jogar uma moeda para chutar a classe do ponto, ela nem mesmo é capaz de overfittar os dados. Utilizaremos o TensorBoard para explorar os gradientes dessa rede mais profunda e tentar analisar essa queda de performance. Em seguida utilizaremos uma nova forma de inicialização dos pesos da rede para tentar recuperar nossa performance e novamente inspecionar os seus gradientes para tentar ganhar algum insight do que está acontecendo dentro dela.

# %% [markdown]
# ___________
#
# ## TensorBoard e Callbacks
#
# O TensorBoard é uma ferramenta de monitoramento e visualização de redes neurais. Nós o utilizaremos para visualizar os gradientes de nossa rede e poder entender mais afundo o que está causando nosso fraco desempenho. Para mais informações sobre o TensorBoard recomendamos este [guia da documentação oficial](https://www.tensorflow.org/tensorboard/get_started). O TensorBoard pode ser iniciado como parte do notebook usando a "magica"  `%load_ext tensorboard` para carrega-lo e `%tensorboard --logdir logs/` para inicia-lo. Outra maneira de utiliza-lo é independente pelo terminal a partir dos logs salvos na pasta `log_dir` com o comando `tensorboard --logdir="logs/"`.
#
# Para utilizar o TensorBoard nós utilizamos um callback ao treinar nossa rede.
#
# [Callbacks](https://keras.io/api/callbacks/#tensorboard) são objetos do Keras capazes de realizar ações em diferentes etapas do treinamento, como a cada final de epoch ou antes de cada mini-batch. Três exemplos interessates de callbacks são o [EarlyStopping](https://keras.io/api/callbacks/early_stopping/) que te permite encerrar o treinamento de sua rede quando você atinge uma performance minima desejada, o [ModelCheckpoint](https://keras.io/api/callbacks/model_checkpoint/) que lhe permite criar checkpoints do seu modelo para poder reiniciar o treinamento sem perder todo seu progresso em caso de algum problema (como seus gradientes explodindo por exemplo) e o [LearningRateScheduler](https://keras.io/api/callbacks/learning_rate_scheduler/) que lhe permite alterar o learning rate do seu otimizador conforme a epoch de treinamento.
#
# O TensorBoard possui um callback que nos permite monitorar o desempenho e parâmetros de nosso modelo ao longo do treinamento, porém para guardar os gradientes da rede necessitamos expandir e adaptar o [callback padrão do TensorBoard](https://keras.io/api/callbacks/tensorboard/).
#
# Nós ja implementamos para vocês uma extensão desse callback no arquivo `utils.py`.
# Para usar este callback basta importa-lo e declara-lo da seguinte maneira:
#
#
# ```python
# from utils import ExtendedTensorBoard
# log_dir = "logs/"
# tensorboard_callback = ExtendedTensorBoard(x=dados_treino, y=labels_treino,log_dir=log_dir,histogram_freq=1)
# ```
# ________________

# %% [markdown]
# ## Definindo nossos dados
# Primeiro definiremos um toy dataset bem simples que utilizaremos para nossos modelos e uma função auxiliar para facilitar a comparação de nossos modelos.
#
#
# Esses dados e redes foram inspirados e adaptados [deste post](https://machinelearningmastery.com/how-to-fix-vanishing-gradients-using-the-rectified-linear-activation-function/).

# %%
# gera dataset de classificação 
X, y = make_circles(n_samples=1000, noise=0.1, random_state=1)

# escala input para [-1,1]
scaler = MinMaxScaler(feature_range=(-1, 1))
X = scaler.fit_transform(X)

# plota visualização do dataset
for i in range(2):
    samples_ix = where(y == i)
    plt.scatter(X[samples_ix, 0], X[samples_ix, 1], label=str(i))
plt.legend()
plt.show()

# separa em teste e treino
n_train = 500
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]

# %%
def run_model(model,log_to_tb= False ,trainX=trainX,trainy=trainy,testX=testX,testy=testy):
    """
    Função auxiliar que recebe um modelo e realiza seu treinamento e avaliação no dataset.
    """
    model.summary()
    
    # compila modelo
    opt = keras.optimizers.SGD(lr=0.01, momentum=0.9)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    #Cria log do modelo pra visualizarmos no TensorBoard se a flag estiver ligada
    callbacks = None
    if log_to_tb==True:
        log_dir = "logs/" + model.name
        callbacks=[ExtendedTensorBoard(x=trainX, y=trainy,log_dir=log_dir,histogram_freq=1)]
    

    # fit modelo
    history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=500, verbose=0, callbacks=callbacks)

    # avalia modelo
    _, train_acc = model.evaluate(trainX, trainy, verbose=0)
    _, test_acc = model.evaluate(testX, testy, verbose=0)
    print("\n")
    print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))


    # plota acurácia/training history
    plt.ylim(0, 1)
    plt.title("Acurácia "+ model.name)
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='test')
    plt.legend()
    plt.show()

# %% [markdown]
# ## Rede rasa
# Aqui temos uma rede rasa com apenas uma camada oculta e uma de output, note que ela é capaz de atingir uma performance razoavel após 300 epochs.
#
# Nos estamos utilizando um inicializador diferente do padrão para os pesos da camada, ele retirar os pesos iniciais a partir de uma distribuição uniforme no intervalo [0,1].

# %%
#define modelo raso
init = RandomUniform(minval=0, maxval=1)

model = keras.Sequential(name="modelo_raso")
model.add(keras.layers.Dense(5,
                       input_dim=2,
                       activation="tanh",
                       kernel_initializer=init,
                       name="raso_1"))
model.add(keras.layers.Dense(1,
                       activation='sigmoid',
                       kernel_initializer=init,
                       name="raso_output"))


run_model(model)
# Out:
# Model: "modelo_raso"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# raso_1 (Dense)               (None, 5)                 15
# _________________________________________________________________
# raso_output (Dense)          (None, 1)                 6
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Train: 0.808, Test: 0.828

# %% [markdown]
# ## Rede funda
#
# Agora tornaremos nossa rede mais funda com 5 camadas ocultas e uma de output, note como a performance cai drasticamente e se torna próxima a um chute aleatório. Embora o modelo seja mais complexo e poderoso nós não conseguimos treina-lo.

# %%
# define modelo mais fundo
init = RandomUniform(minval=0, maxval=1)

model = Sequential(name="modelo_fundo")
model.add(Dense(5, input_dim=2, activation='tanh', kernel_initializer=init,name="funda_1"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_2"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_3"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_4"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_5"))
model.add(Dense(1, activation='sigmoid', kernel_initializer=init,name="funda_output"))


run_model(model,log_to_tb=True)
# Out:
# Model: "modelo_fundo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# funda_1 (Dense)              (None, 5)                 15
# _________________________________________________________________
# funda_2 (Dense)              (None, 5)                 30
# _________________________________________________________________
# funda_3 (Dense)              (None, 5)                 30
# _________________________________________________________________
# funda_4 (Dense)              (None, 5)                 30
# _________________________________________________________________
# funda_5 (Dense)              (None, 5)                 30
# _________________________________________________________________
# funda_output (Dense)         (None, 1)                 6
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Train: 0.528, Test: 0.518

# %% [markdown]
# ### Utilizando inicialização de Xavier Glorot
#
# Agora utilizaremos uma técnica de combate ao vanishing gradient, utilizaremos outro inicializador para os pesos da rede. O [inicializador de Xavier Glorot](http://proceedings.mlr.press/v9/glorot10a/glorot10a.pdf) é o inicializador default de algumas camadas do keras como a camada densa que utilizamos.

# %%
# define modelo mais fundo com inicializador de pesos melhor
model = Sequential(name="modelo_xavier")
model.add(Dense(5, input_dim=2, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_1"))
model.add(Dense(5, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_2"))
model.add(Dense(5, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_3"))
model.add(Dense(5, activation='tanh', kernel_initializer="glorot_uniform",name="xavier_4"))
model.add(Dense(5, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_5"))
model.add(Dense(1, activation='sigmoid', kernel_initializer="glorot_uniform", name="xavier_output"))

run_model(model,log_to_tb=True)
# Out:
# Model: "modelo_xavier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xavier_1 (Dense)             (None, 5)                 15
# _________________________________________________________________
# xavier_2 (Dense)             (None, 5)                 30
# _________________________________________________________________
# xavier_3 (Dense)             (None, 5)                 30
# _________________________________________________________________
# xavier_4 (Dense)             (None, 5)                 30
# _________________________________________________________________
# xavier_5 (Dense)             (None, 5)                 30
# _________________________________________________________________
# xavier_output (Dense)        (None, 1)                 6
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Train: 0.820, Test: 0.848

# %% [markdown]
# ## <font color='blue'>Questão 2 </font>
# Inicialize o TensorBoard e cheque os histogramas e as distribuições dos valores dos gradientes das 2 redes, como eles se diferem de uma rede para outra? Preste atenção em particular para a diferença de amplitude dos seus valores. Que conclusão podemos tirar? Insira/cole imagens do TensorBoard para basear seus argumentos, pode ser uma simples captura de tela.
#
# **Obs:** Você pode filtrar elementos ao escrever a tag "kernel_0_grads" como filtro para facilitar sua exploração dos gradientes dos pesos excluindo os termos de bias/viés.
#
# **Obs2:** Lembre-se de apagar a pasta `logs` se você for retreinar alguma das redes, caso contrário ele irá dar um append nos seus 2 treinamentos e seus graficos de loss e acurácia ficarão errados com loops ligando o começo de um treinamento ao final do outro.
#
# **<font color='red'> Sua resposta aqui </font>**

# %%
#%tensorboard --logdir logs/

# %%
from IPython.display import Image

# %% [markdown]
# <h3>Figura 1 - Gráfico de linha do Tensorborad com a média dos Gradientes por camada da rede profunda com inicialização uniforme - Modelo Fundo</h3>

# %%
Image(filename='figuras/figura1_gradients_modelo_fundo.png')

# %% [markdown]
# <h3>Figura 2 - Gráfico de densidade do Tensorborad com a média dos Gradientes por camada da rede profunda com inicialização uniforme - Modelo Fundo</h3>

# %%
Image(filename='figuras/figura2_gradients_modelo_fundo.png')

# %% [markdown]
# Observando a Figura 1 é possível notar que, embora a rede tenha picos maiores em sua amplitude nas primeiras épocas, os gradientes apresentam pouca atividade, ou seja, a variação é pequena e se concentra em torno de 0, isso é, ao longo de 400 épocas não é muito significativa. Uma coisa a se notar é que, mesmo embora os gradientes estarem no entorno de zero, os intervalos em que eles se encontram variaram entre suas camadas durante as épocas de treinamento.
#
# A camada 4 foi a que mais apresentou variação, no entanto, se observarmos a camada 4 e camada 5 na Figura 2, podemos obervar que durante todas as épocas os picos ficaram concentrados em zero, ou seja, a média dos gradientes obtidos durante todo o treinamento foi de 0 e suas distribuições são quase que identicas, com a diuferença do intervalo em que elas variaram, que neste caso não faz muita diferença porque os valores são bem próximos de zero.
#
# Em relação a camada de saída, através da Figura 1 fica evidente que a média dos gradientes é zero, no entanto, ao observar a Figura 2, podemos notar que houve bastante variabilidade, entre os avalores no entorno de zero, o que caracteriza um pouco de ruído, porém, como essa variabildiade se encontra perto de zero, isso não faz diferença, apenas mostra o quão pequenos os gradientes se tornaram, a ponto de desaparecerem. Através do <i>Tensorboard</i>, foi possível observar no histograma da camada de saída, que nas últimas épocas os gradientes praticamente desapareceram.

# %% [markdown]
# <h3>Figura 3 - Gráfico de linha do Tensorborad com a média dos Gradientes por camada da rede profunda com inicialização Xavier Glorot - Modelo Xavier </h3>

# %%
Image(filename='figuras/figura3_gradients_modelo_xavier.png')

# %% [markdown]
# <h3>Figura 4 - Gráfico de densidade do Tensorborad com a média dos Gradientes por camada da rede profunda com inicialização Xavier Glorot - Modelo Xavier </h3>

# %%
Image(filename='figuras/figura4_gradients_modelo_xavier.png')

# %% [markdown]
# Na figura 3 pode-se observar que existe uma variação maior nos gradientes das camadas ocultas, ou seja, a rede com inicialização Xavier "vê" mais gradientes em relação à rede com inicialização uniforme. A primeira e última camada são as que mais demonstram essa variabilidade, além disso, em relação a rede anterior, essa, demonstra mais consistência no intervalo de variação da amplitude - 0.2 à 0.4  - que se manteve em quase todas as camadas, em oposição a primeira rede que variou -6e-3 à 0.25 com diferentes intervalos de variação entre as camadas ocultas.
#
# Através da Figura 4 podemos observar que os picos também ficaram próximos de 0, mas inversamente ao que se observou na Figura 2, os gradientes com maior concentração são maiores do que zero, porém próximos, o que é comum, já que nas últimas épocas o aprendizado da rede acaba diminuindo bastante. Além disso, uma outra observação a se fazer, é que o formato das distribuições dos gradientes nas camadas exibidas na Figura 4 se assemelham a distribuição normal, exceto pelo formato da distribuição da última camada, e, que as ocorrências dos gradientes estão mais distribuídas no intervalo.
#
# A principais diferenças entre as duas redes se concentram na variabilidade da amplitude em que os pesos variam, na atividade dos gradientes ao longo das camadas ocultas e principalmente na camada de saída, onde a rede com inicialização normal se concentrou em 0 com pouca variabilidade em oposição a segunda rede que demonstrou mais atividade na camada de saída.
